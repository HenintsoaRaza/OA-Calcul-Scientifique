# %% [markdown]
# # <center> TP N°2 </center>
# ### <center> Interpolation Polynômiale (Lagrange, Phénomène de Runge)
#
# </center>
# <div>
#     <center> RAZAFINDRAZAKA Henintsoa </center>
#     <center> Wang James </center>
#     <center> ____________</center>
#     <center> ING5 SI GR02 </center>
#     <center> 20/10/2020 </center>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Déﬁnir un nombre de points N 
N = 2

# Créer une discrétisation 
x = np.linspace(-1, 1, N+1)
print("x : ", x)

# Créer un vecteur (yi) contenant les composantes de f(x) = sin(x)
y = []
for i in range(N+1):
    y.append(np.sin(x[i]))
print("\ny : ", y)
# Out:
# x :  [-1.  0.  1.]
#
# y :  [-0.8414709848078965, 0.0, 0.8414709848078965]

# %%
# Interpolation de Lagrange 
def Lagrange(Xs, x_pt, y_pt):
    N = len(x_pt)
    yL = []
    
    for x in Xs:
        y = 0
        for i in range(N):
            Li = 1
            for k in range(N):
                if k != i:
                    Li *= (x - x_pt[k])/(x_pt[i] - x_pt[k])
            y += y_pt[i] * Li
        yL.append(y)
    return yL

# %%
Xs = np.linspace(-1, 1, 100)
P = Lagrange(Xs, x, y )

print("\nXs = \n", Xs)
print("\nP(Xs) = \n", P)
# Out:
# Xs =
#  [-1.         -0.97979798 -0.95959596 -0.93939394 -0.91919192 -0.8989899
#  -0.87878788 -0.85858586 -0.83838384 -0.81818182 -0.7979798  -0.77777778
#  -0.75757576 -0.73737374 -0.71717172 -0.6969697  -0.67676768 -0.65656566
#  -0.63636364 -0.61616162 -0.5959596  -0.57575758 -0.55555556 -0.53535354
#  -0.51515152 -0.49494949 -0.47474747 -0.45454545 -0.43434343 -0.41414141
#  -0.39393939 -0.37373737 -0.35353535 -0.33333333 -0.31313131 -0.29292929
#  -0.27272727 -0.25252525 -0.23232323 -0.21212121 -0.19191919 -0.17171717
#  -0.15151515 -0.13131313 -0.11111111 -0.09090909 -0.07070707 -0.05050505
#  -0.03030303 -0.01010101  0.01010101  0.03030303  0.05050505  0.07070707
#   0.09090909  0.11111111  0.13131313  0.15151515  0.17171717  0.19191919
#   0.21212121  0.23232323  0.25252525  0.27272727  0.29292929  0.31313131
#   0.33333333  0.35353535  0.37373737  0.39393939  0.41414141  0.43434343
#   0.45454545  0.47474747  0.49494949  0.51515152  0.53535354  0.55555556
#   0.57575758  0.5959596   0.61616162  0.63636364  0.65656566  0.67676768
#   0.6969697   0.71717172  0.73737374  0.75757576  0.77777778  0.7979798
#   0.81818182  0.83838384  0.85858586  0.87878788  0.8989899   0.91919192
#   0.93939394  0.95959596  0.97979798  1.        ]
#
# P(Xs) =
#  [-0.8414709848078965, -0.8244715709733935, -0.8074721571388905, -0.7904727433043877, -0.7734733294698846, -0.7564739156353818, -0.7394745018008788, -0.7224750879663758, -0.7054756741318727, -0.6884762602973699, -0.6714768464628669, -0.6544774326283639, -0.6374780187938611, -0.620478604959358, -0.603479191124855, -0.5864797772903522, -0.5694803634558491, -0.5524809496213462, -0.5354815357868432, -0.5184821219523402, -0.5014827081178374, -0.4844832942833343, -0.4674838804488314, -0.45048446661432834, -0.43348505277982546, -0.4164856389453224, -0.3994862251108195, -0.38248681127631656, -0.3654873974418136, -0.3484879836073107, -0.3314885697728077, -0.31448915593830473, -0.29748974210380175, -0.28049032826929876, -0.2634909144347958, -0.24649150060029285, -0.22949208676578992, -0.21249267293128696, -0.19549325909678397, -0.17849384526228101, -0.16149443142777803, -0.14449501759327507, -0.12749560375877217, -0.11049618992426921, -0.09349677608976623, -0.07649736225526325, -0.05949794842076027, -0.0424985345862573, -0.025499120751754416, -0.00849970691725144, 0.008499706917251534, 0.025499120751754603, 0.04249853458625749, 0.059497948420760366, 0.07649736225526343, 0.09349677608976632, 0.11049618992426939, 0.12749560375877228, 0.14449501759327515, 0.16149443142777822, 0.1784938452622811, 0.19549325909678417, 0.21249267293128707, 0.2294920867657901, 0.246491500600293, 0.2634909144347959, 0.280490328269299, 0.29748974210380186, 0.31448915593830495, 0.3314885697728078, 0.34848798360731087, 0.3654873974418137, 0.3824868112763167, 0.39948622511081966, 0.41648563894532253, 0.43348505277982563, 0.4504844666143285, 0.4674838804488314, 0.4844832942833345, 0.5014827081178374, 0.5184821219523404, 0.5354815357868433, 0.5524809496213463, 0.5694803634558493, 0.5864797772903522, 0.6034791911248552, 0.6204786049593581, 0.6374780187938611, 0.6544774326283641, 0.6714768464628672, 0.68847626029737, 0.705475674131873, 0.7224750879663759, 0.7394745018008788, 0.7564739156353818, 0.7734733294698848, 0.7904727433043877, 0.8074721571388908, 0.8244715709733935, 0.8414709848078965]

# %%
xsin = np.linspace(-1, 1, 100)
# ax = plt.subplots(1, 2, figsize=(10, 5))
plt.plot(xsin, np.sin(xsin), '-r', label='y=sin(x)')
plt.plot(Xs, P, '-b', label='y=P(x)')
fig.legend()

# %%
def interpolation_graph(N):
    x = np.linspace(-1, 1, 100)
    x_pt = np.linspace(-1, 1, N+1)
    y_pt = np.sin(x_pt)

    P = Lagrange(x, x_pt, y_pt )

    plt.plot(x, np.sin(x), '-r', label='y=sin(x)')
    plt.plot(x, P, '-b', label='y=P(x)')
    fig.legend()

# %%
interpolation_graph(1)

# %%
interpolation_graph(2)

# %%
interpolation_graph(3)

# %%
interpolation_graph(4)

# %%
interpolation_graph(99)

# %% [markdown]
# > On constate qu'en augmentant le nombre de points d'interpolation, l'interpolée de sin() ressemble de plus en plus à la fonction sin() elle-même.

# %% [markdown]
# ###  Phénomène de Runge

# %%
def interpolation_Runge(N):
    def f1(x):
        return (1/(1+x**2))
    f = np.vectorize(f1)
    x = np.linspace(-1, 1, 100)
    x_pt = np.linspace(-1, 1, N+1)

    P = Lagrange(x, x_pt, f(x_pt))

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    ax1.plot(x, f(x), '-r', label='y= 1/(1+x^2) ')
    ax2.plot(x, P, '-b', label='y=P(x)')
    fig.legend()

# %%
interpolation_Runge(2)

# %%
interpolation_Runge(3)

# %%
interpolation_Runge(4)

# %%
interpolation_Runge(5)

# %%
interpolation_Runge(10)

# %%
interpolation_Runge(50)

# %%
interpolation_Runge(55)

# %%
interpolation_Runge(60)

# %%
interpolation_Runge(70)

# %%
interpolation_Runge(80)

# %% [markdown]
# > Ici, on constate qu'à partir d'un certain nombre de points d'interpolation (environ 50), l'augmentation du nombre de points $n$ détériore l'approximation de la fonction donnée au lieu de l'améliorer.

# %%
def interpolation_Tchebycheff(N):
    def f1(x):
        return (1/(1+x**2))
    f = np.vectorize(f1)
    
    x = np.linspace(-1, 1, 100)
    
    x_tcheb = np.zeros((N+1,))
    for i in range(x_tcheb.shape[0]):
        x_tcheb[i] = np.cos((2*i+1)*np.pi/(2*N))

    P = Lagrange(x, x_tcheb, f(x_tcheb))
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    ax1.plot(x, f(x), '-r', label='y= 1/(1+x^2) ')
    ax2.plot(x, P, '-b', label='y=P(x)')
    fig.legend()

# %%
interpolation_Tchebycheff(2)

# %%
interpolation_Tchebycheff(3)

# %%
interpolation_Tchebycheff(4)

# %%
interpolation_Tchebycheff(5)

# %%
interpolation_Tchebycheff(10)

# %%
interpolation_Tchebycheff(20)

# %%
interpolation_Tchebycheff(30)
# Out:
# C:\Users\henin\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   if sys.path[0] == '':

# %% [markdown]
# > On remarque qu'en augmentant le nombre de points de Tchebycheff, l'interpolée de f devient de plus en plus semblable à f.
